# %%
from google.colab import drive
drive.mount('/content/drive/')

import os
os.chdir("/content/drive/MyDrive/ResearchProject")
# Out:
# Mounted at /content/drive/

# %%
from irp_functions import *

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

from scipy.stats import ks_2samp
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import classification_report, confusion_matrix, f1_score 
from sklearn.metrics import accuracy_score, recall_score, roc_auc_score, precision_score
from sklearn.preprocessing import StandardScaler
from sklearn.base import clone
from sklearn.neighbors import NearestNeighbors

# %%
root_path = '/content/drive/My Drive/ResearchProject/' 
dataset_path = root_path + 'Datasets/'
covid_filename = root_path + 'Datasets/full_einstein_25col.csv'
df = pd.read_csv(covid_filename)
df.drop(['Date', 'ID'], axis=1, inplace=True)
df['Sex'] = np.where(df['Sex'] == "M", 1, 0)

# %%
os.chdir("/content/drive/MyDrive/ResearchProject/Results/Covid")

# %%
y = df['y'].to_numpy()
X = df.drop(['y'], axis=1).to_numpy()

# %%
results = ten_experiments(X=X, y=y, over_sampler="Outlier_SMOTE",
                          metric="chebyshev", N=100)
data = get_DataFrame_from_results(results)
data.to_csv('100_Chebyshev_Outlier_SMOTE.csv')

# %%
results = ten_experiments(X=X, y=y, over_sampler="Outlier_SMOTE",
                          metric="chebyshev", N=200)
data = get_DataFrame_from_results(results)
data.to_csv('200_Chebyshev_Outlier_SMOTE.csv')

# %%
results = ten_experiments(X=X, y=y, over_sampler="Outlier_SMOTE",
                          metric="chebyshev", N=300)
data = get_DataFrame_from_results(results)
data.to_csv('300_Chebyshev_Outlier_SMOTE.csv')

# %%
results = ten_experiments(X=X, y=y, over_sampler="Outlier_SMOTE",
                          metric="chebyshev", N=400)
data = get_DataFrame_from_results(results)
data.to_csv('400_Chebyshev_Outlier_SMOTE.csv')

# %%
results = ten_experiments(X=X, y=y, over_sampler="Outlier_SMOTE",
                          metric="chebyshev", N=500)
data = get_DataFrame_from_results(results)
data.to_csv('500_Chebyshev_Outlier_SMOTE.csv')

# %%
results = ten_experiments(X=X, y=y, over_sampler="Outlier_SMOTE",
                          metric="chebyshev", N=600)
data = get_DataFrame_from_results(results)
data.to_csv('600_Chebyshev_Outlier_SMOTE.csv')
